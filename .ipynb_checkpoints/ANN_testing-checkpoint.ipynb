# %% [markdown]
# ## Simple multi-layered-perceptron with Focal Loss criterion

# %% [markdown]
# paper reference: https://arxiv.org/pdf/1708.02002.pdf
# **brief explanation on the loss function:**
# - Focal loss is a modified CrossEntropy loss
# - Recall that cross entropy is $CE = \begin{cases}
#       -log(p) & \text{if $y$==1}\\
#       -log(1-p) & \text{otherwise}\\
#     \end{cases} $
#     - for convenience we define $p_t$ to be $p$ when y==1 and $1-p$ otherwise. Therefore $CE = -\log(p_t)$
# - A common regularization method to counteract class imbalance from cross entropy would be to put in a regularizer $\alpha \in [0, 1)$ in front  of CE such that the weight of CE is $alpha$ for y==1 and $1-alpha$ otherwise
# - researchers published the above mentioned paper stated that
#     - `the large class imbalance encountered during training of dense detectors overwhelms the cross entropy loss. Easily classified negatives comprise the majority of the loss and dominate the gradient. While α balances the importance of positive/negative examples, it does not differentiate between easy/hard examples`
# - Therefore, focal loss is postulated with the following formulation
#     - $FL = -(\alpha)(1-p_t)^\gamma CE = -(\alpha)(1-p_t)^\gamma \log(p_t)$

# %%
# overall utility package
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# pytorch library
import torch
from torch import nn
import pandas as pd
# import customm utility packages
from src.FocalLoss import *
from src.custom_dataset import CustomDataset
from src.model import BaseMLP
from src.deployment import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
SEED = 666

# %%
# train = pd.read_csv('train.csv')
# stratify_columns = ['y']
# train, val = train_test_split(train, test_size=0.10, stratify=train[stratify_columns], random_state=SEED)
# val.to_csv('validation.csv', index=False)
# train.to_csv('train_subset.csv', index=False)

# %%
train = pd.read_csv('train_subset.csv')
val = pd.read_csv('validation.csv')

# %%
test = pd.read_csv('hold_out.csv')

# %%
test.shape
# Out:
# (38052, 22)

# %%
train.shape
# Out:
# (194065, 22)

# %% [markdown]
# model is alright after ~10 epochs

# %% [markdown]
# hidden layer = (6, 4)

# %% [markdown]
# baselines:

# %%
rows = []

# %%
rows.append(mlp_run(train, val, batch_size=32, num_iter=100, gamma=4, gpu=False))
# Out:
# Epoch: 10: Train loss: 0.017078198359623514, Validation loss: 0.017172617311326882
# Epoch: 20: Train loss: 0.016939921326772522, Validation loss: 0.017039850879963542
# Epoch: 30: Train loss: 0.016892057946005564, Validation loss: 0.017073622182044768
# Epoch: 40: Train loss: 0.016864303297840017, Validation loss: 0.017093165106076516
# Epoch: 50: Train loss: 0.016844645190733712, Validation loss: 0.01708075635754213
# Epoch: 60: Train loss: 0.016837787971143155, Validation loss: 0.016992648379484783
# Epoch: 70: Train loss: 0.016825118968654837, Validation loss: 0.016982934265660027
# Epoch: 80: Train loss: 0.016823493631254124, Validation loss: 0.016932660171441533
# Epoch: 90: Train loss: 0.016816977565449347, Validation loss: 0.016933278705045934
# Epoch: 100: Train loss: 0.016817986566852856, Validation loss: 0.017061147813958833
# training finished
# roc-auc = 0.849918959451938
# roc-auc = 0.8449229070036994
# train accuracy = 0.9084739685058594
# ...

# %%
rows.append(mlp_run(train, val, batch_size=32, num_iter=100, gamma=5, gpu=False))
# Out:
# Epoch: 10: Train loss: 0.008670828433673575, Validation loss: 0.008716324173627029
# Epoch: 20: Train loss: 0.008639510250124414, Validation loss: 0.008692924727448082
# Epoch: 30: Train loss: 0.008627850915630089, Validation loss: 0.008741970999285203
# Epoch: 40: Train loss: 0.008617370765577918, Validation loss: 0.008811511676578896
# Epoch: 70: Train loss: 0.0009345654998370427, Validation loss: 0.0009426167005056775
# Epoch: 80: Train loss: 0.000934402435369788, Validation loss: 0.0009464030290932397
# Epoch: 90: Train loss: 0.0009342728311949166, Validation loss: 0.000942147470933305
# Epoch: 100: Train loss: 0.0009344030764146446, Validation loss: 0.0009426046494903728
# training finished
# roc-auc = 0.8478770827101777
# roc-auc = 0.8429364812637379
# train accuracy = 0.8466854095458984
# ...

# %%
rows.append(mlp_run(train, val, batch_size=32, num_iter=100, lr=5e-6, criterion = 'focal', alpha = 0.15, gamma = 6, gpu=False, return_prediction = False, return_prob=True))
# Out:
# Epoch: 10: Train loss: 0.0020135851947380335, Validation loss: 0.0020033375925566856
# Epoch: 20: Train loss: 0.0017806391957559933, Validation loss: 0.001792369509711364
# Epoch: 30: Train loss: 0.0017327944707794933, Validation loss: 0.0017464230648340045
# Epoch: 40: Train loss: 0.0017103002374505767, Validation loss: 0.0017256103710786824
# Epoch: 50: Train loss: 0.0016982511221546362, Validation loss: 0.001713942582404672
# Epoch: 60: Train loss: 0.0016907821431766002, Validation loss: 0.0017063846206776135
# Epoch: 70: Train loss: 0.0016858887544952898, Validation loss: 0.001702097875345222
# Epoch: 80: Train loss: 0.0016828262157602312, Validation loss: 0.0016992970160588632
# Epoch: 90: Train loss: 0.0016805370802578793, Validation loss: 0.0016970245978720376
# Epoch: 100: Train loss: 0.0016788770573391055, Validation loss: 0.001695027677494292
# training finished
# roc-auc = 0.8462126405686539
# roc-auc = 0.8419108946492181
# train accuracy = 0.8193337321281433
# ...

# %%
rows.append(mlp_run(train, val, batch_size=32, num_iter=100, lr=5e-6, criterion = 'focal', alpha = 0.15, gamma = 6, gpu=False, return_prediction = False, model=2, return_prob=True))
# Out:
# Epoch: 10: Train loss: 0.0018437788724056264, Validation loss: 0.001847577347017366
# Epoch: 20: Train loss: 0.0017743701926126972, Validation loss: 0.001785184517026069
# Epoch: 30: Train loss: 0.0017408679550212653, Validation loss: 0.0017546187789705845
# Epoch: 40: Train loss: 0.0017204965071473193, Validation loss: 0.0017360417653864543
# Epoch: 50: Train loss: 0.0017074466838926747, Validation loss: 0.001723465991264502
# Epoch: 60: Train loss: 0.0016985994609731564, Validation loss: 0.0017153268250932458
# Epoch: 70: Train loss: 0.00169281815653759, Validation loss: 0.0017098756752305772
# Epoch: 80: Train loss: 0.0016890299264153486, Validation loss: 0.0017060949132903494
# Epoch: 90: Train loss: 0.0016862666013156143, Validation loss: 0.0017040094052571306
# Epoch: 100: Train loss: 0.0016846087209186275, Validation loss: 0.0017017001249531743
# training finished
# roc-auc = 0.8432760456892233
# roc-auc = 0.8383375567299929
# train accuracy = 0.8061371445655823
# ...

# %%
performance = pd.DataFrame(rows).reset_index()

# %%
performance.to_csv('model_performance.csv', index=False)

# %%
performance.drop('roc_curve', axis=1).drop(['index', 'model', 'num_epochs'], axis=1).sort_values(
    by='f1', ascending=False).iloc[[0, 3, 4, 6, 7, 9],:]
# Out:
#           lr criterion  alpha  gamma        f1  precision    recall  roc_score
# 9   0.000100     focal   0.20      7  0.413375   0.342848  0.520433   0.843640
# 10  0.000050     focal   0.20      7  0.407466   0.317160  0.569670   0.842936
# 11  0.000005     focal   0.15      6  0.400726   0.289272  0.651896   0.841911
# 5   0.000100     focal   0.10      1  0.369623   0.240951  0.793205   0.844090
# 4   0.000100     focal   0.10      2  0.369112   0.239671  0.802560   0.844103
# 2   0.000100        ce    NaN      0  0.151643   0.524781  0.088626   0.844997

# %%
roc = performance['roc_curve'].apply(lambda x: pd.Series(x))

# %%
roc.columns = ['FPR', 'TPR', 'threshold']
roc['model'] = performance['index']

# %%
roc_per_model = roc.groupby('model')[['FPR', 'TPR']].apply(
    lambda x: pd.DataFrame({'FPR': x.values[0, 0], 'TPR':x.values[0, 1]})).reset_index().drop('level_1', axis=1)
roc_per_model['model'] = roc_per_model['model'].astype(str)

# %%
roc_per_model.to_csv('roc_per_model.csv', index=False)

# %%
roc_per_model
# Out:
#       model       FPR       TPR
# 0         0  0.000000  0.000000
# 1         0  0.000000  0.000492
# 2         0  0.000000  0.002954
# 3         0  0.000051  0.002954
# 4         0  0.000051  0.004924
# ...     ...       ...       ...
# 47302    12  0.997952  1.000000
# 47303    12  0.998054  1.000000
# 47304    12  0.999181  1.000000
# 47305    12  0.999283  1.000000
# 47306    12  1.000000  1.000000
#
# [47307 rows x 3 columns]

# %%
sns.lineplot(data=roc_per_model.loc[::10], x='FPR', y='TPR', hue='model')
# Out:
# <AxesSubplot:xlabel='FPR', ylabel='TPR'>

# %% [markdown]
# old model 2: 16x4x2

# %%
rows.append(mlp_run(train, val, batch_size=32, 
              num_iter=100, lr=5e-6, criterion = 'focal', alpha = 0.15, gamma = 6, gpu=False, model=2,
              return_prediction = False, return_prob=True, test=test))
# Out:
# Epoch: 10: Train loss: 0.0018386614961535819, Validation loss: 0.001837681478475986
# Epoch: 20: Train loss: 0.0017441161679313576, Validation loss: 0.0017544623835354998
# Epoch: 30: Train loss: 0.001714917885002151, Validation loss: 0.0017278980706764513
# Epoch: 40: Train loss: 0.0017001549988564315, Validation loss: 0.0017146899084904638
# Epoch: 50: Train loss: 0.0016912974214226602, Validation loss: 0.0017059675679688593
# Epoch: 60: Train loss: 0.0016854888424127589, Validation loss: 0.001700567779198941
# Epoch: 70: Train loss: 0.0016813885547149303, Validation loss: 0.001697304974329445
# Epoch: 80: Train loss: 0.001678316719674176, Validation loss: 0.001694351848033851
# Epoch: 90: Train loss: 0.0016759792718420577, Validation loss: 0.0016927485849441634
# Epoch: 100: Train loss: 0.0016739439183246477, Validation loss: 0.0016919612094831794
# training finished
# roc-auc = 0.8461139583192797
# roc-auc = 0.8411166823109305
# roc-auc = 0.844686075444978
# ...

# %% [markdown]
# new model: 16x14x2

# %%
rows.append(mlp_run(train, val, batch_size=32, 
              num_iter=100, lr=5e-6, criterion = 'focal', alpha = 0.15, gamma = 6, gpu=False, model=2,
              return_prediction = False, return_prob=True, test=test))

# %% [markdown]
# ### Ref and conclusions
# - batch size vs training behavior https://medium.com/mini-distill/effect-of-batch-size-on-training-dynamics-21c14f7a716e
# - paper for focal loss: https://arxiv.org/pdf/1708.02002.pdf
# - ROC and PR curve: https://pages.cs.wisc.edu/~jdavis/davisgoadrichcamera2.pdf
#     - if a curve dominates in ROC space, then it also dominates in PR space
#     - an algorithm that optimizes the AUC of ROC may not optimize AUC of PR
#
# - ROC is bad for imbalanced dataset, PR has more explanatory power
